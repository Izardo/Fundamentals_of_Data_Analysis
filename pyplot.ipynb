# %% [markdown]
# <br>
#
# <center><img src='Images/pyplot_logo.png' style="width:200px"></center>
#
# # The matplotlib.pyplot Package
#
# [Documentation](https://matplotlib.org/stable/index.html)
# ***

# %% [markdown]
# <br>
#
# ## Table of Contents
#
# #### [1. Introduction](#Introduction)
#
# #### [2. The Basics](#Basics)
# &nbsp;&nbsp;&nbsp;&nbsp;[- Basic plotting functions](#)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[- Style](#)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[- Subplots](#)<br>
#
# #### [3. Interesting Plots](#)
# &nbsp;&nbsp;&nbsp;&nbsp;[- ](#)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[- ](#)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[- ](#)<br>
#
# #### [4. ](#)
# &nbsp;&nbsp;&nbsp;&nbsp;[- ](#)<br>
#
# #### [5. ](#)
# &nbsp;&nbsp;&nbsp;&nbsp;[- ](#)<br>

# %% [markdown]
# <br>
# <a href="Introduction"></a>
#
# ***
#
# # <center> 1. Introduction</center>
#
# ***

# %% [markdown]
# <center><img src='Images/intro.png' width="150"></center>
#
#
#
# From: <br> https://matplotlib.org/stable/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py
#
#
# - "matplotlib.pyplot is a collection of functions that make matplotlib work like MATLAB."
#
# - "Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc."
#
# - "In matplotlib.pyplot various states are preserved across function calls, so that it keeps track of things like the current figure and plotting area, and the plotting functions are directed to the current axes (please note that "axes" here and in most places in the documentation refers to the axes part of a figure and not the strict mathematical term for more than one axis)."
#
# <br>

# %% [markdown]
# <br>
#
# <a href="Basics"></a>
# ***
#
# # <center> 2. The Basics </center>
# ***

# %% [markdown]
# <center><img src='Images/basics.png' width="150"></center>
#
#
# <br>
#
# ## Import libraries
# ***

# %%
# Plots.
import matplotlib.pyplot as plt

# Dataframes.
import pandas as pd

# Numerical arrays.
import numpy as np

# Random samples.
import random

# Engine to open xlsx files.
import openpyxl as oxl

# %% [markdown]
# <br>
#
# ## (i) Basic plotting functions
# [Source](https://matplotlib.org/stable/tutorials/introductory/pyplot.html)
# ***
#
# `plot()`
# - plots y against x in the form of a line (as default) or another data marker which can be specified as a parameter.
#
# `ylabel()` & `xlabel()`
# - Sets a label for the axis.
#
# `show()`
# - Displays the open figures.
#
# `plt` is the standard alias for matplotlib.pyplot

# %%
# Plot array. 
plt.plot([1, 2, 3, 4])

# Set y label.
plt.ylabel('Y AXIS')

# Show plot.
plt.show()

# %% [markdown]
# Note that <b>when one array is passed through the plt.plot() function, pyplot assumes that array to be the y values and based on those it generates the x values automatically</b>. The reason the starting y value is at zero is, of course, because python is a zero based indexing language - meaning its range always starts at zero as default.

# %% [markdown]
# <br>
#
# ### Passing in both x and y values
# ***

# %%
# Specifying x and y values.
plt.plot([5, 10, 15, 20], [1, 2, 4, 8])
plt.ylabel('y label')
plt.xlabel('x label')
plt.show()

# %% [markdown]
# <br>
#
# ## (ii) Style
# ***

# %% [markdown]
# As mentioned earlier, the plot() function also takes in a third parameter to specify data marker style. <br>
# - The data marker styles are specified as a string containing two values <br>
# - The first character denotes the colour (i.e, g = green etc.)
# - The second character denotes the shape (i.e, ^ = triangle, - = line etc)
#
# The following code will generate a random sample using numpy's arange() function to plot various functions. [https://matplotlib.org/stable/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py]

# %%
# Generate random range from 0 (inclusive) to 10 (exclusive) in intervals of 0.5
x = np.arange(0, 10, 0.5)

# Plot line with red line, blue square, green triangles, and yellow circles. 
plt.plot(x, x, 'r--', x, x**2, 'bs', x, x**3, 'g^', x, x**2.5, 'yo')
plt.show()

# %% [markdown]
# <i>As a side note:</i>
#
# This example also demonstrates how to <b>plot multiple lines</b> on the same plot!
#
# Explanation: We can simply list the x and y values and the line style into plt.plot() to create a single line & for subsequent lines we just add abother 3 values (x, y, line-style).

# %% [markdown]
# #### Default styles
#
# [Default Styles Matplotlib](https://matplotlib.org/stable/users/prev_whats_new/dflt_style_changes.html)
#
# It is good to know that there are around thirty plot styles that can be set as the default.  Have a look at the plot below to see the various plot styles.
#
# <i>The following code was adapted from this [blog](https://www.dunderdata.com/blog/view-all-available-matplotlib-styles).</i>

# %%
# Adapted from: https://www.dunderdata.com/blog/view-all-available-matplotlib-styles

# Generate a random sample.
x = np.arange(-2, 8, .1)

# Y values
y = .1 * x ** 3 - x ** 2 + 3 * x + 2

# COMMENT LATER.
fig = plt.figure(dpi=100, figsize=(9, 18), tight_layout=True)
default_styles = ['default'] + plt.style.available
for i, style in enumerate(default_styles):
    index = 0
    while index < 5:
        with plt.style.context(style):
            ax = fig.add_subplot(10, 3, i + 1)
            ax.plot(x, y)
        index+=1
        ax.set_title(style)

# %%
# View settings for the default plots.
plt.style.library['seaborn-darkgrid']
# Out:
# RcParams({'axes.axisbelow': True,
#           'axes.edgecolor': 'white',
#           'axes.facecolor': '#EAEAF2',
#           'axes.grid': True,
#           'axes.labelcolor': '.15',
#           'axes.linewidth': 0.0,
#           'figure.facecolor': 'white',
#           'font.family': ['sans-serif'],
#           'font.sans-serif': ['Arial',
#                               'Liberation Sans',
#                               'DejaVu Sans',
#                               'Bitstream Vera Sans',
#                               'sans-serif'],
#           'grid.color': 'white',
#           'grid.linestyle': '-',
#           'image.cmap': 'Greys',
#           'legend.frameon': False,
#           'legend.numpoints': 1,
#           'legend.scatterpoints': 1,
#           'lines.solid_capstyle': <CapStyle.round: 'round'>,
#           'text.color': '.15',
#           'xtick.color': '.15',
#           'xtick.direction': 'out',
#           'xtick.major.size': 0.0,
# ...

# %% [markdown]
# <br>
#
# - To set a default style: `plt.style.use()` <br>
# - To reset the default to the default style: `plt.style.use('default')`

# %% [markdown]
# <br>
#
# ### Line properties
# ***
#
# <br>
#
# There are many ways one can <b>alter the attributes of a line</b> this is done so using the Line2D class.
#
#
# A comprehensive list can be found [here](https://matplotlib.org/stable/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D).
#
# As seen above, we can plot a line by using the `plt.plot()` function which creates an instance of [Line2D class](https://matplotlib.org/stable/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D).
#
# <br>
#
# #### 1.  By passing in keyword arguments, we can change the attributes of the line:
# ***
# <br>
#
# <i>Example: setting the linewidth changes the width of the line, imagine that!</i>

# %%
# Create subplots.
fig, (ax1, ax2) = plt.subplots(1, 2)

# Generate y & x values.
y = [1, 2, 3]
x = [1, 2, 3]

# Plot line with specified width. 
ax1.plot(y, x, 'go-', label='line 1', linewidth=4)

# Default linewidth & change line colour.
ax2.plot(y, x, 'ro-', label='line 1')

# %% [markdown]
# <i>Note</i>:
#
# In the square brackets above the plot, the type of data we are dealing with is stated - an instance of the Line2D class.

# %% [markdown]
# <br>
#
# #### 2. Use the setter functions of a Line2D instance:
#
# <br>
#
# <i>Example: using set_antialiased</i>

# %% [markdown]
# <i>From [wikipedia](https://en.wikipedia.org/wiki/Spatial_anti-aliasing):</i><br>
# &nbsp;&nbsp;&nbsp;&nbsp;"In computer graphics, anti-aliasing improves the appearance of "jagged" polygon edges, or "jaggies", so they are smoothed out on the screen."
#
#
# <img src='Images/antialiase.gif' style="width:300px">
# <i>Close up of antialised v. non-antialiased line</i>
#
# <br>
# <br>
# <br>
#
# `set_antialiased()` takes a Boolean value. By setting the value to True, we turn on antialising, visually improving the line and thus, the overall aesthetic of the plot.
#
# <br>
#
# <b>Plot line with antialiasing:</b>

# %%
# y-values.
y = [1, 2, 3, 4]
# x-values
x = [5, 10, 30, 90]

# Plot line.
line, = plt.plot(y, x, 'g-')

# Turn on antialiasing.
line.set_antialiased(True)

# %% [markdown]
# <b>Plot line without antialiasing:</b>

# %%
# Plot line.
line, = plt.plot(y, x, 'g-')

# Turn off antialiasing.
line.set_antialiased(False)

# %% [markdown]
# Note how the line in the second plot appears jagged and less aesthetically pleasing.

# %% [markdown]
# <br>
#
# ## Subplots - multiple figures and axes
# [Subplots Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html#matplotlib.pyplot.subplot)
# ***
#
#
# <br>
#
# The <b>subplots</b> function <b>specifies the figure and axes in which to place plots</b>. The parameters take integer values:
#
# <br>
#
# `subplots(nrows, ncols, index)`
#
# - `nrows` : the row to place plot<br> - The example below has one row.
#
# - `ncols` : the column to place plot<br> - The subplot width.
#
# - `index` : the index the plot will be placed<br> - index starts at the upper left corner and increments to the right i.e., upper left index is one, plot to its right is 2 etc.
#
# A three-digit integer without the commas can also be passed through. It does the exact same as with commas.
#
# <b>Example of subplots using categorical data:</b>

# %%
# Y values.
y = ['Low', 'Medium', 'High']

# X values.
x = [10, 50, 200]

# Set figure size and number of subplots.
plt.figure(figsize=(14, 4))

# Position the subplot & create bar chart.
plt.subplot(1,3,1)
plt.bar(y, x)

# Using the three integers for specifying subplot position
# & create a scatter plot.
plt.subplot(132)
plt.scatter(y, x)

# Specify subplot position & create a simple plot. 
plt.subplot(133)
plt.plot(y, x)

# Give figure a title. 
plt.suptitle('Categorical Data')
plt.show()

# %% [markdown]
# <br>
#
# There are various ways to create the same plots. Below is a more concise way to write the code to create the same plots as above:
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; by using `fig, ax = plt.subplots()` we can unpack the tuple contained in subplots into the fig and ax variables

# %%
# Y values.
y = ['Low', 'Medium', 'High']

# X values.
x = [10, 50, 200]

# Creates figure and axes with 1 row and 3 columns & change figure size.
fig, [ax1, ax2, ax3] = plt.subplots(nrows=1, ncols=3, figsize=(12, 3))

# Set figure size.
fig.set_size_inches(14, 4)

# Plot values with bar plot.
ax1.bar(y, x)

# Plot values with scatter plot. 
ax2.scatter(y, x)

# Plot values with line plot. 
ax3.plot(y, x);

# Give figure a title. 
fig.suptitle('Categorical Data')
plt.show()

# %% [markdown]
# <br>
#
# <b>et voilà!</b>
#
# Same plot output, more concise code! By assigning each axis position to a variable (ax1, ax2 etc.), we ensured easy access to their respective position with minimal code.

# %% [markdown]
# <br>
#
# ## Text
# [Documentation on Pyplot Text](https://matplotlib.org/stable/tutorials/text/text_intro.html)
# ***

# %% [markdown]
# The following code will exemplify the use of the following functions for adding text to a plot:
#
# - <b>set_xlabel, set_ylabel & set_title</b> : used for adding labels to plot (x-label, y-label and title). A string is taken in as a parameter, that is, the text you want to display and also, other parameters for styling the text such as fontsize, color etc. These are all instances of <i>matplotlib.text.Text</i>.
#
# - <b>suptitle</b> : for adding a title to the figure, similar to the functions above it takes in text and other parameters for stying.
#
# - <b>text</b> : adds text to an arbitrary location on the axes. The location is specified with coordinatates. We can specify the style in the same way as those above because it is also an instance of <i>matplotlib.text.Text</i>. You can use the `bbox` parameter to add a box and style to it. A full list of `matplotlib.pyplot.text` options can be found [here](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.text.html).
#
# - <b>annotate</b> : allows you to place text at a location on the plot with the coordinates. How this differs from the text function is that an arrow can be added to point to an area of interest using the `arrowprops` parameter. The text is specified with the `xy` parameter.
#
# <br>
#
# <i>In the example below, we will be <b>plotting a normal distribution</b> with Numpy's random package. You can find the documentation [here](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html).</i>

# %%
# Specifying mean & standard deviation.
mu, sigma = 0, 0.5

# Generate 1000 samples.
norm = np.random.normal(mu, sigma, 1000)

# %%
# Create fig & axes.
fig, ax = plt.subplots(nrows=1, ncols=1)

# Change figure size. 
fig.set_size_inches(9, 6)

# Generate evenly spaced samples over specified intervals.
x = np.random.normal(norm)

# Add axis labels.
ax.set_xlabel("Normal distribution", fontsize=14, color="grey")
ax.set_ylabel("No. of Samples", fontsize=14, color="grey")

# Set plot title. 
ax.set_title("to generate normal samples", fontsize=18, color="grey")

# Sets figure title.
fig.suptitle("Using Numpy's random package", fontsize=20, color="blue")

# Add text in box to indicate location of mean. 
ax.text(0.8, 110, '$\sigma$ = 0.5', color="black", fontsize=16, 
            bbox={'facecolor':'white'}, style='italic')

# Add annotation & arrow to which indicates the mean.
ax.annotate('Mean', xy=(-.04, 100), color='black', fontsize=16, 
            arrowprops=dict(facecolor='yellow', shrink=1), xytext=(-1, 130))

# Plot normal values.
plt.hist(norm, bins=20, color="grey", rwidth=0.9)
plt.show()

# %% [markdown]
# <br>
#
# ***
# # <center> 3. Interesting Plots</center>
# ***

# %% [markdown]
# This section will explore and explain three plots of interest that are created using the Pyplot package.
#
# First, we need some data in order to build our visualisations. A simple data set was chosen from the Central Statistics Office, which contains information on gender representation in various occupations. The original data came in the form ofan excel sheet and it was then converted to CSV format and loaded via Pandas, see code below.
#
# Data Source: [CSO Website](https://www.cso.ie/en/releasesandpublications/ep/p-wamii/womenandmeninireland2019/work/)

# %% [markdown]
# ### Load the data
# ***

# %%
# Load csv, skip unnecessary rows.
df = pd.read_csv('data/gender_occupation2018.csv')

# Remove unnecessary row.
df = df[:-1]

# Set index to be occupation.
df.set_index('Occupation')
# Out:
#                                             Men  Women  Total  WomenPercent
# Occupation
# Managers, directors and senior officials  119.4   63.0  182.4          34.5
# Professionals                             224.4  256.9  481.3          53.4
# Associate professional and technical      147.7  109.9  257.6          42.7
# Administrative and secretarial             51.9  179.3  231.2          77.6
# Skilled trades                            288.3   28.9  317.2           9.1
# Caring, leisure and other services         39.8  152.3  192.1          79.3
# Sales and customer service                 69.7  114.8  184.6          62.2
# Process, plant and machine operatives     157.4   29.6  187.0          15.8
# Elementary                                137.5  119.1  256.6          46.4
# Other/not stated 1                          5.9    7.5   10.0          75.0

# %% [markdown]
# ### Convert values to floats
# ***
#
# It became apparent that some values were non-numeric. For this reason, all the values were converted to floats so that the mathematical and plotting functions could be used on the data.

# %%
# Convert Men & Women values to floats. 
df["Men"] = df["Men"].astype(float)
df["Women"] = df["Women"].astype(float)

# %%
# Assigns columns to variables. 
occ = df["Occupation"]
men = df["Men"]
women = df["Women"]

# %% [markdown]
# Now that the data has been loaded and variables set for each column, a plot can be built.
#
# The `matplotlib.pyplot.barh` plot was chosen to visualise the data.
#
# <br>
#
# ***
# ## <center>1. Unstacked Horizontal Bar Plot</center>
# [Documentation on Pyplot bahr plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.barh.html)
# ***
#
# The barh plot displays `horizontal` bars along the x-axis.
#
# The horizontal bars will represent the number of persons employed in the various  occupations, by gender. These values are specified using the `width` parameter.
#
# The y-axis represents the different occupations, with is specified with the `y` parameter. The code contained in `y_pos` uses Numpy's arange to evenly spread out the occupation labels on the y-axis.

# %%
# Create figure & axis.
fig, ax = plt.subplots()

# Change figure size. 
fig.set_size_inches(12, 10)

# Location for y-labels.
y_pos = np.arange(len(occ))

# Create bars with female values.
ax.barh(y=occ, width=women, align='edge', height=-0.3, alpha=0.7, color='green', label="Women")

# Creating bars with male values.
ax.barh(y=occ, width=men, align='edge', height=0.3, alpha=0.7, color='grey', label="Men")

# Set figure title. 
fig.suptitle("Occupation by Gender", fontsize=30)

# Add axis title.
ax.set_title("in Ireland", fontsize=20, color='grey')

# Set axes labels.
ax.set_ylabel("Occupation", fontsize=16)
ax.set_xlabel("Persons (000s) ", fontsize=16)

# Annotation to highlight occupation with highest employment in occupation.
ax.annotate('Highest no. of male employees', xy=(286, 4.3), color='grey', fontsize=12, 
            arrowprops=dict(facecolor='black', shrink=0.1, width=10), xytext=(286, 4.8))

# Annotation to highlight occupation with highest employment in occupation.
ax.annotate('Highest no. of female employees', xy=(255, 1), color='grey', fontsize=12, 
            arrowprops=dict(facecolor='black', shrink=0.1, width=10), xytext=(255, 1.5))

# Add legend.
ax.legend(fontsize=14)

# Add grid.
ax.grid(True, alpha=0.2)

# Show plots.
plt.show()

# %% [markdown]
# Using the grid function and passing in `True` creates a grid for improved readability. The `alpha` parameter takes a float value, 1.0 is totally opaque and 0.1 being is very translucent. When set to translucent it gives a less "busy" appearence to the plot, making it visually easier on the eye.

# %% [markdown]
# The combination of setting `align` to `edge` and one of the `height` values as a <b>negative value</b> allows us to create an <b>unstacked visualisation of the bars</b>. The final version unstacked version is clearer and easier to interpret.
#
# The <b>stacked version</b> was created by setting `align` to `center`. Note, how it is not as easily interpreted as the unstacked version above.

# %% [markdown]
# <img src='Images/stacked_gender_occ.png' width=900>

# %% [markdown]
# <br>
#
# ***
# ## <center>1. `matplotlib.pyplot.pie`</center>
# [Documentation on Pyplot Pie plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html#matplotlib.pyplot.pie)
# ***

# %% [markdown]
# Colour demo matplotlib https://matplotlib.org/stable/gallery/color/color_demo.html
#
# To get colour codes: https://www.w3schools.com/colors/colors_picker.asp

# %%
# Assign Total column values to variable.
total = df["Total"]
occ = df["Occupation"]
colour = ['#002b80', '#003cb3', '#0055ff', '#3377ff', '#6699ff', 
          '#80aaff', '#b3ccff', '#ccddff', '#e6eeff', '#ffffff']

# %%
# Create figure & axis.
fig, ax = plt.subplots()

# Change figure size. 
fig.set_size_inches(16, 12)

# Generate pie plot on axis. 
ax.pie(x=total, colors=colour, labels=occ);
